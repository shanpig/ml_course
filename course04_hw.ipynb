# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# 自 NIST cccbdb 資料庫網頁找到 dipole moment資訊
chem = pd.read_html("https://cccbdb.nist.gov/diplistx.asp")

# %%
chem[:4]
# Out:
# [                                                   0  \
#  0                                                NaN
#  1  Home All data for one species Geometry Experim...
#  2                                                NaN
#  3  You are here: Experimental > Electrostatics > ...
#
#                                                     1
#  0  Computational Chemistry Comparison and Benchma...
#  1                                                NaN
#  2                                                NaN
#  3                                                NaN  ,
#                    0                              1      2      3       4  \
#  0          Molecule                           name      x      y       z
#  1                H2              Hydrogen diatomic  0.000  0.000   0.000
#  2                D2             Deuterium diatomic    NaN    NaN     NaN
#  3               LiH                Lithium Hydride    NaN    NaN     NaN
#  4               Li2               Lithium diatomic    NaN    NaN     NaN
#  5               Be2             Beryllium diatomic    NaN    NaN     NaN
#  6                BH              Boron monohydride    NaN    NaN     NaN
#  7                C2                Carbon diatomic    NaN    NaN     NaN
#  8                CN                  Cyano radical  0.000  0.000  -1.450
#  9                N2              Nitrogen diatomic    NaN    NaN     NaN
#  10               OH               Hydroxyl radical    NaN    NaN     NaN
#  11              LiO                  lithium oxide    NaN    NaN     NaN
#  12               CO                Carbon monoxide    NaN    NaN     NaN
#  13               NO                   Nitric oxide    NaN    NaN     NaN
#  14              O2-          oxygen diatomic anion    NaN    NaN     NaN
#  15               O2                Oxygen diatomic    NaN    NaN     NaN
#  16               HF              Hydrogen fluoride    NaN    NaN     NaN
#  17              LiF               lithium fluoride    NaN    NaN     NaN
#  18               BF             Boron monofluoride    NaN    NaN     NaN
#  19               CF              Fluoromethylidyne    NaN    NaN   0.645
#  20               FO            Oxygen monofluoride    NaN    NaN     NaN
#  21               F2              Fluorine diatomic    NaN    NaN     NaN
#  22              NaH                 sodium hydride    NaN    NaN   6.400
#  23             NaLi                 lithium sodium    NaN    NaN     NaN
#  24              Na2                Sodium diatomic    NaN    NaN     NaN
#  25              NaF                sodium fluoride    NaN    NaN     NaN
#  26              Mg2             Magnesium diatomic    NaN    NaN     NaN
#  27              Al2              Aluminum diatomic    NaN    NaN     NaN
#  28              AlF          Aluminum monofluoride    NaN    NaN   1.530
#  29              Si2               Silicon diatomic    NaN    NaN     NaN
#  ..              ...                            ...    ...    ...     ...
#  414  CH2CHCH2CH2CH3                      1-pentene  0.377  0.102     NaN
#  415         C6H5CH3                        toluene    NaN    NaN     NaN
#  416           C5H9N                 Pentanenitrile    NaN    NaN     NaN
#  417           C5H9N  Propanenitrile, 2,2-dimethyl-    NaN    NaN     NaN
#  418          C4H10O          1-Propanol, 2-methyl-    NaN    NaN     NaN
#  419          C4H10O                  Ethoxy ethane    NaN    NaN     NaN
#  420          C4H10O                      1-Butanol    NaN    NaN     NaN
#  421          C4H10O         Ethanol, 1,1-dimethyl-    NaN    NaN     NaN
#  422          C5H8O2                  Acetylacetone    NaN    NaN     NaN
#  423       C2H5SC2H5                Diethyl sulfide    NaN    NaN   1.556
#  424           C6H10           Bicyclo[3.1.0]hexane  0.093    NaN   0.168
#  425           C6H10                       1-Hexyne    NaN    NaN     NaN
#  426           C6H10        1-Butyne, 3,3-dimethyl-    NaN    NaN     NaN
#  427           C6H10                    cyclohexene    NaN    NaN   0.331
#  428            C8H8                         cubane  0.000  0.000   0.000
#  429          C5H10O          2H-Pyran, tetrahydro-    NaN    NaN     NaN
#  430        C6H5OCH3                        Anisole  0.694  1.055     NaN
#  431          C5H10S      2H-Thiopyran, tetrahydro-    NaN    NaN     NaN
#  432           C5H12         Propane, 2,2-dimethyl-    NaN    NaN     NaN
#  433           C5H12              Butane, 2-methyl-    NaN    NaN     NaN
#  434          C5H11N                     Piperidine  0.178    NaN   0.800
#  435          C5H11N                     Piperidine  1.069    NaN   0.521
#  436          C6H10O                  cyclohexanone    NaN    NaN     NaN
#  437       CH3COC6H5                   acetophenone    NaN    NaN     NaN
#  438        Si(CH3)4              tetramethylsilane  0.000  0.000   0.000
#  439         C5H11Cl             Pentane, 1-chloro-    NaN    NaN     NaN
#  440      C6H5CH2CH3                   Ethylbenzene    NaN    NaN     NaN
#  441           C10H8                        Azulene    NaN    NaN     NaN
#  442           C7H12                     Norbornane    NaN    NaN     NaN
#  443       C3H7OC3H7              di-n-propyl ether    NaN    NaN     NaN
#
#           5                  6                                                7
#  0      tot              squib                                         commment
#  1    0.000        NSRDS-NBS10                                              NaN
#  2    0.000        NSRDS-NBS10                                              NaN
#  3    5.880        NSRDS-NBS10                                              NaN
#  4    0.000        NSRDS-NBS10                                              NaN
#  5    0.000        NSRDS-NBS10                                              NaN
#  6    1.270   1969Tho/Dal:1155                                          +- 0.21
#  7    0.000        NSRDS-NBS10                                              NaN
#  8    1.450   1968Tho/Dal:2815                                              NaN
#  9    0.000        NSRDS-NBS10                                              NaN
#  10   1.660        NSRDS-NBS10                                              NaN
#  11   6.843   1972Fre/Kle:1467                                              NaN
#  12   0.112        NSRDS-NBS10                                              NaN
#  13   0.153        NSRDS-NBS10                                              NaN
#  14     NaN                NaN                                              NaN
#  15   0.000        NSRDS-NBS10                                              NaN
#  16   1.820        NSRDS-NBS10                                              NaN
#  17   6.284       NISTdiatomic                                              NaN
#  18   0.500     1971Lov/Joh:41                                           +- 0.2
#  19   0.645       NISTdiatomic                                              NaN
#  20   0.004       1992LBII/19c                                           0.0004
#  21   0.000        NSRDS-NBS10                                              NaN
#  22   6.400       1979Dag:2328                                           +- 0.7
#  23   0.460    1972Gra/Dag:710                                       +-0.01 mue
#  24   0.000        NSRDS-NBS10                                              NaN
#  25   8.123       NISTdiatomic                                         +-0.0015
#  26   0.000        NSRDS-NBS10                                              NaN
#  27   0.000        NSRDS-NBS10                                              NaN
#  28   1.530       NISTdiatomic                                              NaN
#  29   0.000        NSRDS-NBS10                                              NaN
#  ..     ...                ...                                              ...
#  414  0.391    2000Fra/Xu:6209                                         x=a, y=b
#  415  0.332         1971Vau:21                                              NaN
#  416  4.120        NSRDS-NBS10                                              NaN
#  417  3.950        NSRDS-NBS10                                              NaN
#  418  1.640        NSRDS-NBS10                                              NaN
#  419  1.150        NSRDS-NBS10                                              NaN
#  420  1.660        NSRDS-NBS10                                              NaN
#  421  1.740         1971Vau:21                                           +-0.04
#  422    NaN                NaN                                              NaN
#  423  1.556   2001Plu/Sue:3057                                     TT Structure
#  424  0.192    NISThydrocarbon                                              NaN
#  425  0.830        NSRDS-NBS10                                              NaN
#  426    NaN    NISThydrocarbon                                              NaN
#  427  0.331    NISThydrocarbon                                              NaN
#  428  0.000                NaN                                              NaN
#  429  1.740  1974Hel/Hel(II/6)                    mua=1.53+-0.02 mub=0.82+-0.02
#  430  1.262   2005Des/Psz:1708                                         x=a, y=b
#  431  1.781    1975Kit/Mal:179  +-0.010, mu_a = 1.684+-0.009, mu_c=0.578+-0.002
#  432  0.000        NSRDS-NBS10                                              NaN
#  433  0.130        NSRDS-NBS10                                              NaN
#  434  0.820    1981Par/Buc:465                mua=0.178+-0.007 muc=0.800+-0.020
#  435  1.189    1981Par/Buc:465                mua=1.069+-0.015 muc=0.521+-0.007
#  436  3.020         1971Vau:21                                              NaN
#  437  3.020        NSRDS-NBS10                                              NaN
#  438  0.000                NaN                                      by symmetry
#  439  2.160        NSRDS-NBS10                                              NaN
#  440  0.590        NSRDS-NBS10                                              NaN
#  441  0.800        NSRDS-NBS10                                              NaN
#  442  0.091    NISThydrocarbon                                              NaN
#  443  1.210        NSRDS-NBS10                                              NaN
#
#  [444 rows x 8 columns],
#                     0                                                  1  \
#  0              squib                                          reference
#  1         1954Kis:86  P Kisluk "Dipole Moments, Nuclear Quadrupole C...
#  2    1955Kra/Dai:184  J Kraitchman, BP Dailey "The Microwave Spectru...
#  3        1957Mag:223  DW Magnuson "Microwave Spectrum and Molecular ...
#  4       1959Cur:1529  RF Curl "Microwave Spectrum, Barrier to Intern...
#  5        1961Lau:291  VW Laurie "Microwave Spectrum of cis-Difluoroe...
#  6    1961Laurie:1516  VW Laurie "MICROWAVE SPECTRUM OF ISOBUTYLENE D...
#  7        1962Lev:276  IN Levine "The microwave spectrum of formaldox...
#  8   1962Tol/Gwi:1119  WM Tolles, WD Gwinn, "Sturcture and Dipole mom...
#  9       1963Nel:2382  R Nelson "Microwave Spectrum, Molecular Struct...
#  10    1964Sas/Cur:77  KVL Sastry, RF Curl "MICROWAVE SPECTRUM OF N-M...
#  11  1965Hun/Lea:1931  RH Hunt, RA Leacock, CW Peters, KT Hecht "Inte...
#  12   1966Bak/Chr:883  B Bak, JJ Christiansen, K Kuntsmann, L Nygaard...
#  13       1966Bee:414  JF Beecher "Microwave Spectrum, Dipole Moment,...
#  14  1966Har/Cox:5049  Harmoy, M; Cox, K. "Microwave Spectrum, Dipole...
#  15  1967Coo/Kir:4521  RL Cook, WH Kirchhoff "Further Investigations ...
#  16      1967Kir:1312  WH Kirchhoff "The Microwave Spectrum and Dipol...
#  17  1968Leg/Mil:1736  AC Legon, DJ Millen "The Microwave Spectrum, S...
#  18  1968Poc/Bal:1072  JM Pochan, JE Baldwin, WH Flygare "Microwave S...
#  19  1968Tho/Dal:2815  R Thomson, FW Dalby "Experimental determinatio...
#  20  1969Mir/Cor:4118  AM Mirri, C Corbelli, P Forti "Stark Effect an...
#  21   1969Rog/Sch:397  Rogowski, Schwendeman, Microwave Spectra, Barr...
#  22  1969Tho/Dal:1155  R Thomson, FW Dalby "An experimental determina...
#  23    1970Kon/Hir:97  S Kondo, E Hirota "Microwave spectrum and Inte...
#  24   1971Byf/Car:271  CR Byfleet, A Carrington, DK Russell, "Electri...
#  25   1971Hir/Cur:358  C Hirose, RF Curl Jr, "Microwave Spectrum, Con...
#  26  1971Kri/Sae:4553  LC Krisher, E Saegebarth "MICROWAVE SPECTRUM O...
#  27    1971Lov/Joh:41  FJ Lovas, DR Johnson "Microwave Spectrum of BF...
#  28    1971Ola/Vir:18  P Olavi, I Virtanen, P Ruostesuo "Dipole Momen...
#  29        1971Vau:21  WE Vaughan, Digest of literature on dielectric...
#  ..               ...                                                ...
#  53  1981Kuc/Sue:2561  Kuczkowski, Suenram, Lovas, Microwave Spectra,...
#  54   1981Par/Buc:465  JE Parkin, PJ Buckley, CC Costain "The Micorwa...
#  55  1982Chr/Gri:1378  D Christen, JH Griffiths, J Sheridan "The Micr...
#  56   1983Tan/Tan:425  K Tanaka, T Tanaka "CO2 and N2O Laser Stark Sp...
#  57   1983Tho/Sue:167  LR Thorne, RD Suenram, FJ Lovas "Microwave spe...
#  58       1984Gra/Gub  CG Gray, KE Gubbins "Theory of molecular fluid...
#  59   1984Rod/Bro:447  M Rodler, RD Brown, PD Godfrey, LM Tack "Gener...
#  60   1986Sue/Lov:406  RD Suenram, FJ Lovas "The microwave Spectrum a...
#  61  1987Ebe/Han:1948  WL Ebenstein, C Hanning, SL Shostak, JS Muente...
#  62    1988Kan/Yam:89  H Kanata, S Yamamoto, S Saito "The dipole mome...
#  63   1989Kog/Tak:467  Y Koga, H Takeo, S Kondo, M Sugie, C Matsumura...
#  64  1991Dur/Fen:1827  JR Durig, FS Feng, A Wang, HV Phan "Conformati...
#  65      1992LBII/19c  Landolt-Bornstein Numerical Data and Functiona...
#  66   1995Lov/Kaw:201  FJ Lovas, Y Kawashima, JU Grabow, RD Suenram, ...
#  67  1996Mod/DeN:1645  G Modugno, P De Natale, M Bellini, M Inguscio,...
#  68  1997Bau/Bei:7558  A Bauder, A Beil, D Luckhaus, F Muller, M Quac...
#  69  1998Wei/Hai:3134  MA Weibel, TD Hain, TJ Curtiss "Hexapole-selec...
#  70   2000Fra/Xu:6209  GT Fraser, LH Xu, RD Suenram, CL Lugez "Rotati...
#  71  2001Plu/Sue:3057  DF Plusquellic, RD Suenram, B Mate, JO Jensen,...
#  72     2002Dur/Jin:1  JR Durig, Y Jin, HV Phan, J Liu, DT Durig "Far...
#  73  2005Des/Psz:1708  O Desyatnyk, L Pszczolkowski, S Thorwirth, TM ...
#  74   2007Caz/Puz:112  G Cazzoli, C Puzzarini, A Baldacci, A Baldan "...
#  75   2008Woh/Sch:119  K Wohlfart, M Schnell, J-U Grabow, J Kupper "P...
#  76   2011Kan/Her:173  P Kania, M Hermanns, S Brunken, HSP Muller, TF...
#  77   2011Le/Ste:9370  A Le, TC Steimle "Optical Stark Spectroscopy o...
#  78      NISTdiatomic  NIST Diatomic Spectral Database (www.physics.n...
#  79   NISThydrocarbon  NIST Hydrocarbon spectral database (http://www...
#  80     NISTtriatomic  NIST Triatomic Spectral Database (http://www.p...
#  81       NSRDS-NBS10  R. D. Nelson Jr., D. R. Lide, A. A. Maryott "S...
#  82           webbook  NIST Chemistry Webbook (http://webbook.nist.go...
#
#                                 2
#  0                            DOI
#  1              10.1063/1.1739863
#  2              10.1063/1.1740525
#  3              10.1063/1.1743675
#  4              10.1063/1.1730232
#  5              10.1063/1.1731582
#  6              10.1063/1.1701038
#  7   10.1016/0022-2852(62)90028-0
#  8              10.1063/1.1732702
#  9              10.1063/1.1701456
#  10             10.1063/1.1725653
#  11             10.1063/1.1696228
#  12             10.1063/1.1727700
#  13  10.1016/0022-2852(66)90165-2
#  14           10.1021/ja00973a066
#  15             10.1063/1.1701662
#  16           10.1021/ja00982a006
#  17          10.1039/J19680001736
#  18           10.1021/ja01006a049
#  19               10.1139/p68-652
#  20             10.1063/1.1671680
#  21             10.1063/1.1670810
#  22               10.1139/p69-144
#  23  10.1016/0022-2852(70)90077-9
#  24     10.1080/00268977100100251
#  25  10.1016/0022-2852(71)90119-6
#  26             10.1063/1.1674721
#  27             10.1063/1.1675537
#  28                           NaN
#  29                           NaN
#  ..                           ...
#  53           10.1021/ja00400a013
#  54  10.1016/0022-2852(81)90040-0
#  55         10.1515/zna-1981-1220
#  56  10.1016/0022-2852(83)90253-9
#  57              10.1063/1.444528
#  58                           NaN
#  59  10.1016/0009-2614(84)87068-2
#  60  10.1016/0022-2852(86)90136-0
#  61              10.1063/1.453723
#  62  10.1016/0022-2852(88)90109-9
#  63  10.1016/0022-2852(89)90013-1
#  64               10.1139/v91-268
#  65                           NaN
#  66                           NaN
#  67       10.1364/JOSAB.13.001645
#  68              10.1063/1.473759
#  69              10.1063/1.475711
#  70              10.1063/1.481220
#  71             10.1063/1.1385527
#  72       10.1023/A:1013410428690
#  73              10.1039/b501041a
#  74     10.1016/j.jms.2006.11.004
#  75     10.1016/j.jms.2007.10.006
#  76     10.1016/j.jms.2011.04.013
#  77             10.1021/jp110838j
#  78               10.18434/T4T59X
#  79               10.18434/T4PC70
#  80               10.18434/T4DW2S
#  81          10.6028/NBS.NSRDS.10
#  82               10.18434/T4D303
#
#  [83 rows x 3 columns]]

# %% [markdown]
# ### 由上表可得知， "chem" 此  dataframe  有過多不必要之表格，
# ### 因此我們逐一檢查其內容後發現， chem[1]  才是真正  dipole moment  相關的表格。

# %%
chem_table = chem[1].copy()     # chem[1] 為想要之表格
chem_table.head(20)
# Out:
#            0                      1      2      3       4      5  \
# 0   Molecule                   name      x      y       z    tot
# 1         H2      Hydrogen diatomic  0.000  0.000   0.000  0.000
# 2         D2     Deuterium diatomic    NaN    NaN     NaN  0.000
# 3        LiH        Lithium Hydride    NaN    NaN     NaN  5.880
# 4        Li2       Lithium diatomic    NaN    NaN     NaN  0.000
# 5        Be2     Beryllium diatomic    NaN    NaN     NaN  0.000
# 6         BH      Boron monohydride    NaN    NaN     NaN  1.270
# 7         C2        Carbon diatomic    NaN    NaN     NaN  0.000
# 8         CN          Cyano radical  0.000  0.000  -1.450  1.450
# 9         N2      Nitrogen diatomic    NaN    NaN     NaN  0.000
# 10        OH       Hydroxyl radical    NaN    NaN     NaN  1.660
# 11       LiO          lithium oxide    NaN    NaN     NaN  6.843
# 12        CO        Carbon monoxide    NaN    NaN     NaN  0.112
# 13        NO           Nitric oxide    NaN    NaN     NaN  0.153
# 14       O2-  oxygen diatomic anion    NaN    NaN     NaN    NaN
# 15        O2        Oxygen diatomic    NaN    NaN     NaN  0.000
# 16        HF      Hydrogen fluoride    NaN    NaN     NaN  1.820
# 17       LiF       lithium fluoride    NaN    NaN     NaN  6.284
# 18        BF     Boron monofluoride    NaN    NaN     NaN  0.500
# 19        CF      Fluoromethylidyne    NaN    NaN   0.645  0.645
#
#                    6         7
# 0              squib  commment
# 1        NSRDS-NBS10       NaN
# 2        NSRDS-NBS10       NaN
# 3        NSRDS-NBS10       NaN
# 4        NSRDS-NBS10       NaN
# 5        NSRDS-NBS10       NaN
# 6   1969Tho/Dal:1155   +- 0.21
# 7        NSRDS-NBS10       NaN
# 8   1968Tho/Dal:2815       NaN
# 9        NSRDS-NBS10       NaN
# 10       NSRDS-NBS10       NaN
# 11  1972Fre/Kle:1467       NaN
# 12       NSRDS-NBS10       NaN
# 13       NSRDS-NBS10       NaN
# 14               NaN       NaN
# 15       NSRDS-NBS10       NaN
# 16       NSRDS-NBS10       NaN
# 17      NISTdiatomic       NaN
# 18    1971Lov/Joh:41    +- 0.2
# 19      NISTdiatomic       NaN

# %% [markdown]
# ### 另外，表格中之標題並非第一列，因此將資料第二列標題移到第一列。

# %%
colname = chem_table.loc[0, :]
chem_table_new = chem_table.loc[1:, :].copy()
chem_table_new.columns = colname

# %%
chem_table_new.head(20)
# Out:
# 0  Molecule                   name      x      y       z    tot  \
# 1        H2      Hydrogen diatomic  0.000  0.000   0.000  0.000
# 2        D2     Deuterium diatomic    NaN    NaN     NaN  0.000
# 3       LiH        Lithium Hydride    NaN    NaN     NaN  5.880
# 4       Li2       Lithium diatomic    NaN    NaN     NaN  0.000
# 5       Be2     Beryllium diatomic    NaN    NaN     NaN  0.000
# 6        BH      Boron monohydride    NaN    NaN     NaN  1.270
# 7        C2        Carbon diatomic    NaN    NaN     NaN  0.000
# 8        CN          Cyano radical  0.000  0.000  -1.450  1.450
# 9        N2      Nitrogen diatomic    NaN    NaN     NaN  0.000
# 10       OH       Hydroxyl radical    NaN    NaN     NaN  1.660
# 11      LiO          lithium oxide    NaN    NaN     NaN  6.843
# 12       CO        Carbon monoxide    NaN    NaN     NaN  0.112
# 13       NO           Nitric oxide    NaN    NaN     NaN  0.153
# 14      O2-  oxygen diatomic anion    NaN    NaN     NaN    NaN
# 15       O2        Oxygen diatomic    NaN    NaN     NaN  0.000
# 16       HF      Hydrogen fluoride    NaN    NaN     NaN  1.820
# 17      LiF       lithium fluoride    NaN    NaN     NaN  6.284
# 18       BF     Boron monofluoride    NaN    NaN     NaN  0.500
# 19       CF      Fluoromethylidyne    NaN    NaN   0.645  0.645
# 20       FO    Oxygen monofluoride    NaN    NaN     NaN  0.004
#
# 0              squib commment
# 1        NSRDS-NBS10      NaN
# 2        NSRDS-NBS10      NaN
# 3        NSRDS-NBS10      NaN
# 4        NSRDS-NBS10      NaN
# 5        NSRDS-NBS10      NaN
# 6   1969Tho/Dal:1155  +- 0.21
# 7        NSRDS-NBS10      NaN
# 8   1968Tho/Dal:2815      NaN
# 9        NSRDS-NBS10      NaN
# 10       NSRDS-NBS10      NaN
# 11  1972Fre/Kle:1467      NaN
# 12       NSRDS-NBS10      NaN
# 13       NSRDS-NBS10      NaN
# 14               NaN      NaN
# 15       NSRDS-NBS10      NaN
# 16       NSRDS-NBS10      NaN
# 17      NISTdiatomic      NaN
# 18    1971Lov/Joh:41   +- 0.2
# 19      NISTdiatomic      NaN
# 20      1992LBII/19c   0.0004

# %% [markdown]
# * chem : 原始資料
# * chem[1] : 為 molecule 部分(我們要的)資料，但多一列
# * chem_table ：為 chem[1] 之複製檔，避免更改到原始檔。
# * chem_table_new : 為已更改過標題之資料檔
#
# 然而因本資料中，許多分子為線性分子，無xyz軸之分，故chem_table僅有total dipole moment，無各軸分量；
# 也有一些分子因不明原因(或未測定、或未有確切值)而資料為空，接下來將所有無值空格一律填入-1，以免未來分析出現error。

# %%
# 將各行 NaN值代換為 -1
for i in chem_table_new[2: -1]:
    chem_table_new[i].fillna(value=-1, inplace=True)
chem_table_new.head(20)
# Out:
# 0  Molecule                   name      x      y       z    tot  \
# 1        H2      Hydrogen diatomic  0.000  0.000   0.000  0.000
# 2        D2     Deuterium diatomic     -1     -1      -1  0.000
# 3       LiH        Lithium Hydride     -1     -1      -1  5.880
# 4       Li2       Lithium diatomic     -1     -1      -1  0.000
# 5       Be2     Beryllium diatomic     -1     -1      -1  0.000
# 6        BH      Boron monohydride     -1     -1      -1  1.270
# 7        C2        Carbon diatomic     -1     -1      -1  0.000
# 8        CN          Cyano radical  0.000  0.000  -1.450  1.450
# 9        N2      Nitrogen diatomic     -1     -1      -1  0.000
# 10       OH       Hydroxyl radical     -1     -1      -1  1.660
# 11      LiO          lithium oxide     -1     -1      -1  6.843
# 12       CO        Carbon monoxide     -1     -1      -1  0.112
# 13       NO           Nitric oxide     -1     -1      -1  0.153
# 14      O2-  oxygen diatomic anion     -1     -1      -1     -1
# 15       O2        Oxygen diatomic     -1     -1      -1  0.000
# 16       HF      Hydrogen fluoride     -1     -1      -1  1.820
# 17      LiF       lithium fluoride     -1     -1      -1  6.284
# 18       BF     Boron monofluoride     -1     -1      -1  0.500
# 19       CF      Fluoromethylidyne     -1     -1   0.645  0.645
# 20       FO    Oxygen monofluoride     -1     -1      -1  0.004
#
# 0              squib commment
# 1        NSRDS-NBS10       -1
# 2        NSRDS-NBS10       -1
# 3        NSRDS-NBS10       -1
# 4        NSRDS-NBS10       -1
# 5        NSRDS-NBS10       -1
# 6   1969Tho/Dal:1155  +- 0.21
# 7        NSRDS-NBS10       -1
# 8   1968Tho/Dal:2815       -1
# 9        NSRDS-NBS10       -1
# 10       NSRDS-NBS10       -1
# 11  1972Fre/Kle:1467       -1
# 12       NSRDS-NBS10       -1
# 13       NSRDS-NBS10       -1
# 14                -1       -1
# 15       NSRDS-NBS10       -1
# 16       NSRDS-NBS10       -1
# 17      NISTdiatomic       -1
# 18    1971Lov/Joh:41   +- 0.2
# 19      NISTdiatomic       -1
# 20      1992LBII/19c   0.0004

# %% [markdown]
# 接下來簡單的將資料進行分析，以 total dipole moment 大小之四捨五入分類。
#
# 此時在資料中會多出一直行稱為  dipole_cat  的分類。

# %%
# 新增一直行分類，以 total dipole moment四捨五入之值取到整數。
chem_table_new.loc[:, "dipole_cat"] = np.around(chem_table_new.loc[:, "tot"].astype(float), decimals=0)
# 將任何 total dipole moment大於8之資料都 merge到 8.0類別中。
chem_table_new.loc[:, "dipole_cat"].where(chem_table_new.loc[:, "dipole_cat"] < 8, 8.0, inplace=True)
chem_table_new.head(20)
# Out:
# 0  Molecule                   name      x      y       z    tot  \
# 1        H2      Hydrogen diatomic  0.000  0.000   0.000  0.000
# 2        D2     Deuterium diatomic     -1     -1      -1  0.000
# 3       LiH        Lithium Hydride     -1     -1      -1  5.880
# 4       Li2       Lithium diatomic     -1     -1      -1  0.000
# 5       Be2     Beryllium diatomic     -1     -1      -1  0.000
# 6        BH      Boron monohydride     -1     -1      -1  1.270
# 7        C2        Carbon diatomic     -1     -1      -1  0.000
# 8        CN          Cyano radical  0.000  0.000  -1.450  1.450
# 9        N2      Nitrogen diatomic     -1     -1      -1  0.000
# 10       OH       Hydroxyl radical     -1     -1      -1  1.660
# 11      LiO          lithium oxide     -1     -1      -1  6.843
# 12       CO        Carbon monoxide     -1     -1      -1  0.112
# 13       NO           Nitric oxide     -1     -1      -1  0.153
# 14      O2-  oxygen diatomic anion     -1     -1      -1     -1
# 15       O2        Oxygen diatomic     -1     -1      -1  0.000
# 16       HF      Hydrogen fluoride     -1     -1      -1  1.820
# 17      LiF       lithium fluoride     -1     -1      -1  6.284
# 18       BF     Boron monofluoride     -1     -1      -1  0.500
# 19       CF      Fluoromethylidyne     -1     -1   0.645  0.645
# 20       FO    Oxygen monofluoride     -1     -1      -1  0.004
#
# 0              squib commment  dipole_cat
# 1        NSRDS-NBS10       -1         0.0
# 2        NSRDS-NBS10       -1         0.0
# 3        NSRDS-NBS10       -1         6.0
# 4        NSRDS-NBS10       -1         0.0
# 5        NSRDS-NBS10       -1         0.0
# 6   1969Tho/Dal:1155  +- 0.21         1.0
# 7        NSRDS-NBS10       -1         0.0
# 8   1968Tho/Dal:2815       -1         1.0
# 9        NSRDS-NBS10       -1         0.0
# 10       NSRDS-NBS10       -1         2.0
# 11  1972Fre/Kle:1467       -1         7.0
# 12       NSRDS-NBS10       -1         0.0
# 13       NSRDS-NBS10       -1         0.0
# 14                -1       -1        -1.0
# 15       NSRDS-NBS10       -1         0.0
# 16       NSRDS-NBS10       -1         2.0
# 17      NISTdiatomic       -1         6.0
# 18    1971Lov/Joh:41   +- 0.2         0.0
# 19      NISTdiatomic       -1         1.0
# 20      1992LBII/19c   0.0004         0.0

# %% [markdown]
# 最後我們看一下各分類之資料共有幾筆：

# %%
chem_table_new["dipole_cat"].value_counts().sort_index()
# Out:
# -1.0      4
#  0.0    118
#  1.0    121
#  2.0    121
#  3.0     36
#  4.0     25
#  5.0      4
#  6.0      5
#  7.0      3
#  8.0      6
# Name: dipole_cat, dtype: int64

# %% [markdown]
# 如上列可得知大部分分子之 total dipole moment集中於 0~2debye之間，且有一部分拖尾狀況，
#
# 未來若要以此資料進行訓練，可能還需後續處理。
