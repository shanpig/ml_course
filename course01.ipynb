# %%
# %matplotlib inline 

import matplotlib.pyplot as plt 
import numpy as np

angle=np.arange(0.0, 2*np.pi, 0.01)
x1=2.0+np.cos(angle) 
y1=2.0+np.sin(angle)

x2=3.1+np.cos(angle) 
y2=1.0+np.sin(angle)

x3=4.2+np.cos(angle) 
y3=2.0+np.sin(angle)

x4=5.3+np.cos(angle) 
y4=1.0+np.sin(angle)

x5=6.4+np.cos(angle) 
y5=2.0+np.sin(angle)

plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3)
plt.plot(x4, y4)
plt.plot(x5, y5)

# %%
print ('hello')
# Out:
# hello

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

r=np.linspace(0, 10, 3142)
xd=yd=30.0
angle = np.arange(0, 10*pi, 0.01)
x = xd+r*np.cos(angle)
y = yd+r*np.sin(angle)
plt.plot(x, y)

# %% [markdown]
# ## 圖片
#
# ![discovery](discovery.png)
# ![pig](piggy.mov)

# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas

a='hello'
b="hello"
# Out:
# '\na\na\n'
